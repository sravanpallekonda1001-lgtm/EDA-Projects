# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pokemon_data.csv")
df.head()
# Out:
#    dexnum        name  generation  type1   type2         species  height  \
# 0       1   Bulbasaur           1  Grass  Poison    Seed Pokémon     0.7
# 1       2     Ivysaur           1  Grass  Poison    Seed Pokémon     1.0
# 2       3    Venusaur           1  Grass  Poison    Seed Pokémon     2.0
# 3       4  Charmander           1   Fire     NaN  Lizard Pokémon     0.6
# 4       5  Charmeleon           1   Fire     NaN   Flame Pokémon     1.1
#
#    weight  ability1     ability2  ... catch_rate  base_friendship  base_exp  \
# 0     6.9  Overgrow  Chlorophyll  ...         45               50        64
# 1    13.0  Overgrow  Chlorophyll  ...         45               50       142
# 2   100.0  Overgrow  Chlorophyll  ...         45               50       236
# 3     8.5     Blaze  Solar Power  ...         45               50        62
# 4    19.0     Blaze  Solar Power  ...         45               50       142
#
#    growth_rate  egg_group1  egg_group2  percent_male  percent_female  \
# 0  Medium Slow      Grass      Monster          87.5            12.5
# 1  Medium Slow      Grass      Monster          87.5            12.5
# 2  Medium Slow      Grass      Monster          87.5            12.5
# 3  Medium Slow     Dragon      Monster          87.5            12.5
# 4  Medium Slow     Dragon      Monster          87.5            12.5
#
#   egg_cycles  special_group
# 0         20       Ordinary
# 1         20       Ordinary
# 2         20       Ordinary
# 3         20       Ordinary
# 4         20       Ordinary
#
# [5 rows x 29 columns]

# %%
df.tail()
# Out:
#       dexnum          name  generation     type1    type2  \
# 1020    1021   Raging Bolt           9  Electric   Dragon
# 1021    1022  Iron Boulder           9      Rock  Psychic
# 1022    1023    Iron Crown           9     Steel  Psychic
# 1023    1024     Terapagos           9    Normal      NaN
# 1024    1025     Pecharunt           9    Poison    Ghost
#
#                   species  height  weight          ability1 ability2  ...  \
# 1020      Paradox Pokémon     5.2   480.0    Protosynthesis      NaN  ...
# 1021      Paradox Pokémon     1.5   162.5       Quark Drive      NaN  ...
# 1022      Paradox Pokémon     1.6   156.0       Quark Drive      NaN  ...
# 1023         Tera Pokémon     0.2     6.5        Tera Shift      NaN  ...
# 1024  Subjugation Pokémon     0.3     0.3  Poison Puppeteer      NaN  ...
#
#      catch_rate  base_friendship  base_exp  growth_rate    egg_group1  \
# 1020         10                —         —         Slow  Undiscovered
# 1021         10                —         —         Slow  Undiscovered
# 1022         10                —         —         Slow  Undiscovered
# 1023        255                —         —         Slow  Undiscovered
# 1024          3                —         —         Slow  Undiscovered
#
#       egg_group2  percent_male  percent_female egg_cycles    special_group
# 1020         NaN           NaN             NaN          —  Ancient Paradox
# 1021         NaN           NaN             NaN          —   Future Paradox
# 1022         NaN           NaN             NaN          —   Future Paradox
# 1023         NaN          50.0            50.0          —        Legendary
# 1024         NaN           NaN             NaN          —         Mythical
#
# [5 rows x 29 columns]

# %% [markdown]
# Removing duplicate values

# %%
df.isna().sum()
# Out:
# dexnum               0
# name                 0
# generation           0
# type1                0
# type2              499
# species              0
# height               0
# weight               0
# ability1             0
# ability2           167
# hidden_ability     495
# hp                   0
# attack               0
# defense              0
# sp_atk               0
# sp_def               0
# speed                0
# total                0
# ev_yield             0
# catch_rate           0
# base_friendship      0
# base_exp             0
# growth_rate          0
# egg_group1           0
# egg_group2         746
# percent_male       155
# percent_female     155
# egg_cycles           0
# special_group        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['dexnum', 'name', 'generation', 'type1', 'type2', 'species', 'height',
#        'weight', 'ability1', 'ability2', 'hidden_ability', 'hp', 'attack',
#        'defense', 'sp_atk', 'sp_def', 'speed', 'total', 'ev_yield',
#        'catch_rate', 'base_friendship', 'base_exp', 'growth_rate',
#        'egg_group1', 'egg_group2', 'percent_male', 'percent_female',
#        'egg_cycles', 'special_group'],
#       dtype='object')

# %%
df.shape
# Out:
# (1025, 29)

# %%
null_percentages = (df.isna().sum() / len(df)) * 100
null_percentages = null_percentages.sort_values(ascending=False)
print("Percentage of null values per column:")
print(null_percentages)
# Out:
# Percentage of null values per column:
# egg_group2         72.780488
# type2              48.682927
# hidden_ability     48.292683
# ability2           16.292683
# percent_male       15.121951
# percent_female     15.121951
# type1               0.000000
# species             0.000000
# height              0.000000
# ability1            0.000000
# generation          0.000000
# dexnum              0.000000
# name                0.000000
# attack              0.000000
# hp                  0.000000
# weight              0.000000
# defense             0.000000
# total               0.000000
# sp_atk              0.000000
# sp_def              0.000000
# speed               0.000000
# base_friendship     0.000000
# catch_rate          0.000000
# ev_yield            0.000000
# base_exp            0.000000
# egg_group1          0.000000
# growth_rate         0.000000
# egg_cycles          0.000000
# special_group       0.000000
# dtype: float64

# %%
df
# Out:
#       dexnum          name  generation     type1    type2  \
# 0          1     Bulbasaur           1     Grass   Poison
# 1          2       Ivysaur           1     Grass   Poison
# 2          3      Venusaur           1     Grass   Poison
# 3          4    Charmander           1      Fire      NaN
# 4          5    Charmeleon           1      Fire      NaN
# ...      ...           ...         ...       ...      ...
# 1020    1021   Raging Bolt           9  Electric   Dragon
# 1021    1022  Iron Boulder           9      Rock  Psychic
# 1022    1023    Iron Crown           9     Steel  Psychic
# 1023    1024     Terapagos           9    Normal      NaN
# 1024    1025     Pecharunt           9    Poison    Ghost
#
#                   species  height  weight          ability1     ability2  ...  \
# 0            Seed Pokémon     0.7     6.9          Overgrow  Chlorophyll  ...
# 1            Seed Pokémon     1.0    13.0          Overgrow  Chlorophyll  ...
# 2            Seed Pokémon     2.0   100.0          Overgrow  Chlorophyll  ...
# 3          Lizard Pokémon     0.6     8.5             Blaze  Solar Power  ...
# 4           Flame Pokémon     1.1    19.0             Blaze  Solar Power  ...
# ...                   ...     ...     ...               ...          ...  ...
# 1020      Paradox Pokémon     5.2   480.0    Protosynthesis          NaN  ...
# 1021      Paradox Pokémon     1.5   162.5       Quark Drive          NaN  ...
# 1022      Paradox Pokémon     1.6   156.0       Quark Drive          NaN  ...
# 1023         Tera Pokémon     0.2     6.5        Tera Shift          NaN  ...
# 1024  Subjugation Pokémon     0.3     0.3  Poison Puppeteer          NaN  ...
#
#      catch_rate  base_friendship  base_exp  growth_rate    egg_group1  \
# 0            45               50        64  Medium Slow        Grass
# 1            45               50       142  Medium Slow        Grass
# 2            45               50       236  Medium Slow        Grass
# 3            45               50        62  Medium Slow       Dragon
# 4            45               50       142  Medium Slow       Dragon
# ...         ...              ...       ...          ...           ...
# 1020         10                —         —         Slow  Undiscovered
# 1021         10                —         —         Slow  Undiscovered
# 1022         10                —         —         Slow  Undiscovered
# 1023        255                —         —         Slow  Undiscovered
# 1024          3                —         —         Slow  Undiscovered
#
#       egg_group2  percent_male  percent_female egg_cycles    special_group
# 0        Monster          87.5            12.5         20         Ordinary
# 1        Monster          87.5            12.5         20         Ordinary
# 2        Monster          87.5            12.5         20         Ordinary
# 3        Monster          87.5            12.5         20         Ordinary
# 4        Monster          87.5            12.5         20         Ordinary
# ...          ...           ...             ...        ...              ...
# 1020         NaN           NaN             NaN          —  Ancient Paradox
# 1021         NaN           NaN             NaN          —   Future Paradox
# 1022         NaN           NaN             NaN          —   Future Paradox
# 1023         NaN          50.0            50.0          —        Legendary
# 1024         NaN           NaN             NaN          —         Mythical
#
# [1025 rows x 29 columns]

# %%
df=df.drop("egg_group2",axis=1)

# %%
df.columns
# Out:
# Index(['dexnum', 'name', 'generation', 'type1', 'type2', 'species', 'height',
#        'weight', 'ability1', 'ability2', 'hidden_ability', 'hp', 'attack',
#        'defense', 'sp_atk', 'sp_def', 'speed', 'total', 'ev_yield',
#        'catch_rate', 'base_friendship', 'base_exp', 'growth_rate',
#        'egg_group1', 'percent_male', 'percent_female', 'egg_cycles',
#        'special_group'],
#       dtype='object')

# %%
df=df.drop('hidden_ability',axis=1)

# %%
df=df.drop("type2",axis=1)

# %%
df.columns
# Out:
# Index(['dexnum', 'name', 'generation', 'type1', 'species', 'height', 'weight',
#        'ability1', 'ability2', 'hp', 'attack', 'defense', 'sp_atk', 'sp_def',
#        'speed', 'total', 'ev_yield', 'catch_rate', 'base_friendship',
#        'base_exp', 'growth_rate', 'egg_group1', 'percent_male',
#        'percent_female', 'egg_cycles', 'special_group'],
#       dtype='object')

# %%
arr=df.isna().sum()/len(df)*100
sort=arr.sort_values(ascending=False)
print(sort)
# Out:
# ability2           16.292683
# percent_male       15.121951
# percent_female     15.121951
# generation          0.000000
# name                0.000000
# type1               0.000000
# height              0.000000
# weight              0.000000
# species             0.000000
# dexnum              0.000000
# hp                  0.000000
# ability1            0.000000
# attack              0.000000
# defense             0.000000
# speed               0.000000
# total               0.000000
# sp_atk              0.000000
# sp_def              0.000000
# catch_rate          0.000000
# ev_yield            0.000000
# base_friendship     0.000000
# base_exp            0.000000
# egg_group1          0.000000
# growth_rate         0.000000
# egg_cycles          0.000000
# special_group       0.000000
# dtype: float64

# %%
categorical=df.select_dtype=["object","categorical"]
categorical
# Out:
# /tmp/ipykernel_4506/1718475296.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   categorical=df.select_dtype=["object","categorical"]
# ['object', 'categorical']

# %%
df.shape[1]
# Out:
# 26

# %%
df["ability2"]=df["ability2"].fillna(df["ability2"].mode()[0])

# %%
df["ability2"].isna().sum()
# Out:
# np.int64(0)

# %%
import numpy as np
df["percent_male"]=df["percent_male"].fillna(df["percent_male"].mean()).astype("int")

# %%
df["percent_male"].unique()
# Out:
# array([ 87,  50,   0, 100,  25,  75,  54,  12])

# %%
values=df.isnull().sum()
result=values.sort_values(ascending=False)
print(result)
# Out:
# percent_female     155
# dexnum               0
# generation           0
# type1                0
# species              0
# height               0
# weight               0
# ability1             0
# ability2             0
# name                 0
# hp                   0
# attack               0
# sp_atk               0
# defense              0
# speed                0
# total                0
# ev_yield             0
# sp_def               0
# catch_rate           0
# base_friendship      0
# growth_rate          0
# base_exp             0
# egg_group1           0
# percent_male         0
# egg_cycles           0
# special_group        0
# dtype: int64

# %% [markdown]
# define outliers

# %%
import numpy as np

# %%
df["percent_female"].skew()
# Out:
# np.float64(-0.04214783499294134)

# %%
df["percent_female"].kurt()
# Out:
# np.float64(1.3079607959212667)

# %%
df["percent_female"]=df["percent_female"].fillna(df["percent_female"].mean())

# %%
values=df.isnull().sum()
result=values.sort_values(ascending=False)
print(result)
# Out:
# dexnum             0
# name               0
# generation         0
# type1              0
# species            0
# height             0
# weight             0
# ability1           0
# ability2           0
# hp                 0
# attack             0
# defense            0
# sp_atk             0
# sp_def             0
# speed              0
# total              0
# ev_yield           0
# catch_rate         0
# base_friendship    0
# base_exp           0
# growth_rate        0
# egg_group1         0
# percent_male       0
# percent_female     0
# egg_cycles         0
# special_group      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# 1. Distribution of HP
# - Plot a histogram of the hp column using Seaborn or Matplotlib.
# - Add a reasonable number of bins (e.g., 10–20).
# - Task: What range of HP values seems most common?

# %%
plt.figure(figsize=(6,4))
sns.histplot(x="hp",data=df,bins=20,kde=True)
plt.title("histogram of hp column")
plt.show()

# %% [markdown]
# 2. Distribution of Speed
# - Plot a histogram of the speed column.
# - Task: Are there more slow Pokémon or fast Pokémon? (Look at where most bars are concentrated.)

# %%
plt.figure(figsize=(6,4))
sns.histplot(x="speed",bins=20,kde=True,data=df)
plt.title("histogram of speed column")
plt.show()

# %% [markdown]
# -  3. Count of Pokémon by
# Primary Type (type1)
# - Create a countplot of type1 to see how many Pokémon exist of each primary type.
# - Task: Which primary type has the most Pokémon? Which types are relatively rare?

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="type1",data=df)
plt.title("countplot of type1")
plt.show()

# %% [markdown]
# - 4. Average Attack by Primary Type
# - Group the data by type1 and calculate the mean attack for each type.
# - Plot this as a bar plot (type on x-axis, average attack on y-axis).
# - Task: Which type1 has the highest average attack?

# %%
df1 = df.groupby("type1")["attack"].agg("mean")
plt.figure(figsize=(6,4))
sns.barplot(x="type1",y="attack",data=df,edgecolor="black")
plt.title("average attack by title1")
plt.show()

# %% [markdown]
# 5. Speed by Primary Type (Boxplot)
# - Draw a boxplot with:
# - x-axis: type1
# - y-axis: speed
# - Task: Which type1 tends to have the fastest Pokémon (higher median)? Which types show a large spread in Speed? (Hint: You may rotate x-axis labels for readability.)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="type1",y="speed",data=df,)
plt.title("speed by type1")
plt.show()

# %% [markdown]
# - 6. Comparison Across Generations: Count of Pokémon
# - Use a countplot (or bar plot) to show the number of Pokémon in each generation.
# - Task: Which Generation has the most Pokémon in this dataset?

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="generation",data=df)
plt.title("count of pokemon in each generation")
plt.show()

# %% [markdown]
# - 7. Average Total Stats by Generation
# - Group by generation and compute the average of total.
# - Plot a bar plot of generation vs average total.
# - Task: Do later generations seem to have higher or lower total stats on average?

# %%
df2=df.groupby("generation")["total"].agg("mean")
sns.barplot(x="generation",y="total",data=df,edgecolor="black")
plt.title("average total stats by generation")
plt.show()

# %% [markdown]
# - 8. Relationship Between Attack and Defense
# - Make a scatter plot:
# - x-axis: attack
# - y-axis: defense.
# - Task: Is there any visible relationship between attack and defense (e.g., do high-attack Pokémon also tend to have high defense)?

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="attack",y="defense",data=df)
plt.title("relation between attack and defense")
plt.show()

# %% [markdown]
# - 9. Relationship Between Speed and Total
# - Create a scatter plot of:
# - x-axis: speed
# - y-axis: total.
# - Task: Do faster Pokémon generally have higher total stats, or is it spread out?

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="speed",y="total",data=df)
plt.title("relation between speed and total")
plt.show()

# %% [markdown]
# 10. Heatmap of Correlations Between Stats
# Select only numeric stat columns: ['hp', 'attack', 'defense', 'sp_atk', 'sp_def', 'speed', 'total'].
# Compute their correlation matrix using df[cols].corr().
# Plot a heatmap of this correlation matrix using sns.heatmap (with annot=True if possible).
# Task: Which pair of stats seems most strongly positively correlated? Is any stat weakly related to the others?

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[["hp","attack","defense","sp_atk","sp_def","speed","total"]].corr(),annot=True)
plt.title("heatmap of correlation between stats")
plt.show()
